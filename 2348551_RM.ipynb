# %% [markdown]
# <a href="https://colab.research.google.com/github/szm5417/szm5417/blob/main/2348551_RM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/detailed_data.csv')

# %%
data.head()
# Out:
#   name of company                                  college name       region  \
# 0         XORIANT               XAVIER INSTITUTE OF ENGINEERING       MUMBAI
# 1         XORIANT  INDIRA COLLEGE OF ENGINEERING AND MANAGEMENT         PUNE
# 2         XORIANT           VISHWAKARMA INSTITUTE OF TECHNOLOGY         PUNE
# 3         QUINNOX                 PILLAI COLLEGE OF ENGINEERING  NAVI MUMBAI
# 4         QUINNOX  THAKUR COLLEGE OF ENGINEERING AND TECHNOLOGY       MUMBAI
#
#    year  Salary
# 0  2018  657673
# 1  2018  657673
# 2  2018  446973
# 3  2018  446973
# 4  2018  446973

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name of company  462 non-null    object
#  1   college name     462 non-null    object
#  2   region           462 non-null    object
#  3   year             462 non-null    int64
#  4   Salary           462 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 18.2+ KB

# %%
data.describe()
# Out:
#               year        Salary
# count   462.000000  4.620000e+02
# mean   2017.279221  5.360360e+05
# std       1.120680  4.355012e+05
# min    2014.000000  1.108300e+04
# 25%    2017.000000  2.995120e+05
# 50%    2018.000000  4.469730e+05
# 75%    2018.000000  7.418210e+05
# max    2018.000000  1.801956e+06

# %%
data.isnull().sum()
# Out:
# name of company    0
# college name       0
# region             0
# year               0
# Salary             0
# dtype: int64

# %%
data.nunique()
# Out:
# name of company    122
# college name        23
# region               4
# year                 5
# Salary             122
# dtype: int64

# %%
data.sort_values(by="Salary", ascending=False).head(10)
# Out:
#      name of company                           college name  region  year  \
# 391              UBS  PUNE INSTITUTE OF COMPUTER TECHNOLOGY    PUNE  2018
# 392         SYMANTEC           ARMY INSTITUTE OF TECHNOLOGY    PUNE  2018
# 393         SYMANTEC            COLLEGE OF ENGINEERING PUNE    PUNE  2018
# 394         SYMANTEC             MIT COLLEGE OF ENGINEERING    PUNE  2018
# 395         SYMANTEC  PUNE INSTITUTE OF COMPUTER TECHNOLOGY    PUNE  2015
# 128   MORGAN STANLEY   THADOMAL SHAHANI ENGINEERING COLLEGE  MUMBAI  2018
# 136   MORGAN STANLEY            COLLEGE OF ENGINEERING PUNE    PUNE  2018
# 127  LARSEN & TOUBRO    VISHWAKARMA INSTITUTE OF TECHNOLOGY    PUNE  2018
# 137   MORGAN STANLEY  PUNE INSTITUTE OF COMPUTER TECHNOLOGY    PUNE  2015
# 138   MORGAN STANLEY  PUNE INSTITUTE OF COMPUTER TECHNOLOGY    PUNE  2016
#
#       Salary
# 391  1801956
# 392  1801956
# 393  1801956
# 394  1801956
# 395  1801956
# 128  1764982
# 136  1764982
# 127  1764982
# 137  1764982
# ...

# %%
data.corr()
# Out:
# <ipython-input-9-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             year    Salary
# year    1.000000 -0.076162
# Salary -0.076162  1.000000

# %%
sns.heatmap(data.corr(), annot=True)
plt.rcParams['figure.figsize'] = (15,10)
plt.show()
# Out:
# <ipython-input-10-0009ad4e55b4>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True)

# %%
data.groupby('Salary').mean()
# Out:
# <ipython-input-11-644aeb4c9e99>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Salary').mean()
#                 year
# Salary
# 11083    2018.000000
# 11637    2018.000000
# 12995    2017.333333
# 15948    2016.000000
# 16625    2018.000000
# ...              ...
# 1656475  2017.166667
# 1724538  2018.000000
# 1764367  2018.000000
# 1764982  2016.333333
# 1801956  2017.400000
#
# [122 rows x 1 columns]

# %%
df = data.groupby('college name')[['region', 'year',
       'Salary','name of company']].mean().sort_values(by = "Salary", ascending = False)
# Out:
# <ipython-input-23-5d3bc3b88de1>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   'Salary','name of company']].mean().sort_values(by = "Salary", ascending = False)

# %%
df3 = df.transpose()

# %%
df3.plot()
# Out:
# <Axes: >

# %%
plt.scatter(data['year'],data['college name'],c=data['Salary'])
